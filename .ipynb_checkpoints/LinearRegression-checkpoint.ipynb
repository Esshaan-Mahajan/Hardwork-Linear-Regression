# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load and Visualize data

# %%
X=pd.read_csv("Training Data/Linear_X_Train.csv")
y=pd.read_csv("Training Data/Linear_Y_Train.csv")

# %%
X= X.values
y= y.values


u=X.mean()
std=X.std()


X=(X-u)/std

# %%
plt.style.use('seaborn')
plt.scatter(X,y,color='green')
plt.title("hardwork vs performance")
plt.xlabel("Hardwork")
plt.ylabel("performance")
plt.show()

# %%
X.shape
# Out:
# (3750, 1)

# %%
y.shape
# Out:
# (3750, 1)

# %% [markdown]
# # Linear Regression Algorithm

# %%
def hypothesis(x,theta):
    y_=theta[0]+theta[1]*x
    return y_

def gradient(X,Y,theta):
    m=X.shape[0]
    grad=np.zeros((2,))
    for i in range(m):
        x=X[i]
        y_=hypothesis(x,theta)
        y=Y[i]
        grad[0]+= (y_ - y)
        grad[1]+= (y_ - y)*x        
        
    return grad/m    

def error(X,Y,theta):
    total_error = 0.0
    m=X.shape[0]
    for i in range(m):
        y_ = hypothesis(X[i],theta)
        total_error+= (y_ - Y[i])**2

    return total_error/m

def gradientDescent(X,Y,max_steps=100,rate=0.1):
    
    theta=np.zeros((2,))
    error_list=[]
    theta_list = []
    
    for i in range(max_steps):
        grad=gradient(X,Y,theta)
        
        e= error(X,Y,theta)
        error_list.append(e)
        
        theta[0] = theta[0] - rate * grad[0]
        theta[1] = theta[1] - rate * grad[1]   
        
        theta_list.append((theta[0],theta[1]))
        
    return (theta,error_list,theta_list)

# %%
theta,error_list,theta_list = gradientDescent(X,y)

# %%
plt.plot(error_list)
plt.title("reduction in error over iterations")
plt.show()

# %% [markdown]
# # Predictions and best fit

# %%
y_= hypothesis(X,theta)
print(y_)
# Out:
# [[-19.5733619 ]
#  [-43.69571729]
#  [ 86.4848761 ]
#  ...
#  [-20.85044708]
#  [138.70197319]
#  [-35.87897262]]

# %%
plt.scatter(X,y)
plt.plot(X,y_,color='orange',label='Predictions')
plt.legend()
plt.show()

# %%
X_test=pd.read_csv('Test Cases/Linear_X_Test.csv').values
y_test = hypothesis(X_test,theta)

# %%
df = pd.DataFrame(data=y_test,columns = ['y'])
print(df)
print(X_test)
# Out:
#                y
# 0    -149.370696
# 1     -68.754940
# 2    -201.486870
# 3     221.234243
# 4      47.906897
# ...          ...
# 1245  -12.744630
# 1246   75.171802
# 1247   10.912138
# 1248  -21.532358
# 1249  -53.684600
#
# [1250 rows x 1 columns]
# [[-1.87794441]
#  [-0.86903192]
#  [-2.53018242]
#  ...
#  [ 0.12800782]
#  [-0.27803759]
#  [-0.68042543]]

# %%
df.to_csv("y_predictions2.csv",index=False)

# %% [markdown]
# # Calculating Score

# %%
def r2_score(Y,Y_):
    num=np.sum((Y-Y_)**2)
    denum=np.sum((Y-Y.mean())**2)    
    score=(1-num/denum)
    return score*100

# %% [markdown]
# # Visualizing loss function , gradient descent,theta updates

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
theta
# Out:
# array([ 0.6838508 , 79.90361453])

# %%
T0 = np.arange(-40,40)
T1 = np.arange(40,120,1)

T0,T1 = np.meshgrid(T0,T1)
J = np.zeros(T0.shape)

for i in range(J.shape[0]):
    for j in range(J.shape[1]):
        y_  = T1[i,j]*X + T0[i,j]
        J[i,j] = np.sum((y-y_)**2)/y.shape[0]

# %%
fig = plt.figure()
axes = fig.gca(projection='3d')
axes.plot_surface(T0,T1,J,cmap='rainbow')
# Out:
# <ipython-input-49-eaa252676b19>:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axes = fig.gca(projection='3d')

# %%
#Countors

fig = plt.figure()
axes = fig.gca(projection='3d')
axes.contour(T0,T1,J,cmap='rainbow')
# Out:
# <ipython-input-50-3f93d910bbf7>:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axes = fig.gca(projection='3d')

# %%
## ploting changes in theta
theta_list = np.array(theta_list)


plt.plot(theta_list[:,0],label = "theta0 ")
plt.plot(theta_list[:,1],label = "theta1 ")
plt.legend()
plt.show()

# %%
# Trajectory traced by theta updates
fig = plt.figure()
axes = fig.gca(projection='3d')
axes.plot_surface(T0,T1,J,cmap='rainbow')
axes.scatter(theta_list[:,0],theta_list[:,1],error_list)
plt.show()
# Out:
# <ipython-input-54-53a92cf38399>:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axes = fig.gca(projection='3d')

# %%
fig = plt.figure()
axes = fig.gca(projection='3d')
axes.contour(T0,T1,J,cmap='rainbow')
axes.scatter(theta_list[:,0],theta_list[:,1],error_list)
plt.show()
# Out:
# <ipython-input-55-22d3f52da9e2>:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axes = fig.gca(projection='3d')

# %%
# 2d contour
plt.contour(T0,T1,J,cmap='rainbow')
plt.scatter(theta_list[:,0],theta_list[:,1])
plt.show()

# %%
np.save('theta_list.npy',theta_list)
